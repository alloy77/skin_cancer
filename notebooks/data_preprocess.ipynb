# %% [markdown]
# # <h1> Data preprocessing for Skin Cancer Detection.
# This notebook contains the steps for preprocessing the skin lesion images.
#
# ### The following steps will be implemented for preprocessing the images:
# • Load the dataset \
# • Remove the duplicates \
# • Splitting the dataset into train, validation and test sets \
# • Processing the images \
# • Resize the images and rescale the picture values \
# • And all the necessary steps required for efficient training of the models.

# %% [markdown]
# ## 1. Import Libraries
#
# First, we need to import the necessary libraries.

# %%
import os
import shutil
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

# %% [markdown]
# ## 2. Define Directories
#
# Next, we define the directories for the raw data and the processed data.

# %%
# Disable oneDNN optimizations
BASE_DIR = r"ML-MinorProject\ISIC-2020 Dataset"
TRAIN_DIR = os.path.join(BASE_DIR, "ISIC_2020_Training_JPEG", "train")
TEST_DIR = os.path.join(BASE_DIR, "ISIC_2020_Test_JPEG", "ISIC_2020_Test_Input")
PROCESSED_TRAIN_DIR = os.path.join(BASE_DIR, "processed_train")
PROCESSED_VAL_DIR = os.path.join(BASE_DIR, "processed_val")
PROCESSED_TEST_DIR = os.path.join(BASE_DIR, "processed_test")

# %% [markdown]
# ## 3. Load and Preprocess Data
#
# We load the data, remove duplicates, and split it into training, validation, and test sets.

# %%
# Load duplicate image list
duplicate_csv_path = os.path.join(BASE_DIR, "ISIC_2020_Training_Duplicates.csv")
duplicate_df = pd.read_csv(duplicate_csv_path)

# Keep only image_name_1 and remove image_name_2
duplicate_images = set(duplicate_df['image_name_1'] + ".jpg")  # Assuming filenames end with .jpg

# Collect image filenames
image_filenames = glob.glob(os.path.join(TRAIN_DIR, "*.jpg"))

# Remove duplicate images
filtered_filenames = [img for img in image_filenames if os.path.basename(img) not in duplicate_images]

# Create dataframe
labels = ["malignant" if "malignant" in fname.lower() else "benign" for fname in filtered_filenames]
data_df = pd.DataFrame({"filename": filtered_filenames, "label": labels})

# Train-validation split
train_df, val_df = train_test_split(data_df, test_size=0.2, random_state=42, stratify=data_df["label"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Load duplicate image list
#       2 duplicate_csv_path = os.path.join(BASE_DIR, "ISIC_2020_Training_Duplicates.csv")
# ----> 3 duplicate_df = pd.read_csv(duplicate_csv_path)
#       5 # Keep only image_name_1 and remove image_name_2
#       6 duplicate_images = set(duplicate_df['image_name_1'] + ".jpg")  # Assuming filenames end with .jpg
#
# File ~\.conda\envs\py310\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\.conda\envs\py310\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\.conda\envs\py310\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\.conda\envs\py310\lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\.conda\envs\py310\lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ML-MinorProject\\ISIC-2020 Dataset\\ISIC_2020_Training_Duplicates.csv'

# %% [markdown]
# ## 4. Create Directories for Organized Dataset
#
# We create directories for the processed training, validation, and test datasets.

# %%
# Create directories if they don't exist
os.makedirs(PROCESSED_TRAIN_DIR, exist_ok=True)
os.makedirs(PROCESSED_VAL_DIR, exist_ok=True)
os.makedirs(PROCESSED_TEST_DIR, exist_ok=True)

for category in ["benign", "malignant"]:
    os.makedirs(os.path.join(PROCESSED_TRAIN_DIR, category), exist_ok=True)
    os.makedirs(os.path.join(PROCESSED_VAL_DIR, category), exist_ok=True)
    os.makedirs(os.path.join(PROCESSED_TEST_DIR, category), exist_ok=True)

# %% [markdown]
# ## 5. Load Test Ground Truth
#
# We load the test ground truth data from the `ISIC_2020_Test_GroundTruth.csv` file.

# %%
# Load test ground truth
test_ground_truth_csv_path = os.path.join(BASE_DIR, "ISIC_2020_Test_GroundTruth.csv")
test_ground_truth_df = pd.read_csv(test_ground_truth_csv_path)
# Create the 'label' column based on the 'target' column
test_ground_truth_df["label"] = test_ground_truth_df["target"].apply(lambda x: "malignant" if x == 1 else "benign")

# Map 'image_name' to file paths
test_ground_truth_df["filename"] = test_ground_truth_df["isic_id"].apply(lambda x: os.path.join(TEST_DIR, f"{x}.jpg"))

# Debug: Check the first few rows of the ground truth DataFrame
print("test_ground_truth_df:")
print(test_ground_truth_df.head())

# Filter out rows where the file does not exist in TEST_DIR
test_ground_truth_df = test_ground_truth_df[test_ground_truth_df["filename"].apply(os.path.exists)]

# Debug: Check the number of benign and malignant images
print("Number of benign images in ground truth:", len(test_ground_truth_df[test_ground_truth_df["label"] == "benign"]))
print("Number of malignant images in ground truth:", len(test_ground_truth_df[test_ground_truth_df["label"] == "malignant"]))

# Create test_df directly from the ground truth DataFrame
test_df = test_ground_truth_df[["filename", "label"]]

# Debug: Check the first few rows of test_df
print("test_df:")
print(test_df.head())

# Debug: Check malignant images in test_df
test_df_malignant = test_df[test_df["label"] == "malignant"]
print("test_df_malignant:")
print(test_df_malignant.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Load test ground truth
#       2 test_ground_truth_csv_path = os.path.join(BASE_DIR, "ISIC_2020_Test_GroundTruth.csv")
# ----> 3 test_ground_truth_df = pd.read_csv(test_ground_truth_csv_path)
#       4 # Create the 'label' column based on the 'target' column
#       5 test_ground_truth_df["label"] = test_ground_truth_df["target"].apply(lambda x: "malignant" if x == 1 else "benign")
#
# File ~\.conda\envs\py310\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\.conda\envs\py310\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\.conda\envs\py310\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\.conda\envs\py310\lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\.conda\envs\py310\lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ML-MinorProject\\ISIC-2020 Dataset\\ISIC_2020_Test_GroundTruth.csv'

# %%
test_df_malignant = test_df[test_df["label"] == "malignant"]
print("test_df_malignant: ", test_df_malignant.head())
# Out:
# test_df_malignant:                                                filename      label
# 24   G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\...  malignant
# 66   G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\...  malignant
# 102  G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\...  malignant
# 110  G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\...  malignant
# 192  G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\...  malignant

# %% [markdown]
# ## 6. Move test images
# We now move the test images to `processed_test` directory according to their classes.

# %%
# Move test images to processed_test directory
for _, row in test_df.iterrows():
    label = row["label"]
    src_path = row["filename"]
    dest_dir = os.path.join(PROCESSED_TEST_DIR, label)

    # Ensure the destination directory exists
    os.makedirs(dest_dir, exist_ok=True)

    # Check if the source file exists
    if os.path.exists(src_path):
        try:
            # Move the file
            shutil.move(src_path, os.path.join(dest_dir, os.path.basename(src_path)))
            print(f"Moved {src_path} to {dest_dir}")
jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_0341315.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_0343131.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_0343283.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_0346766.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_0347157.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_0348342.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_0350347.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_0350470.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_0351156.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_0351912.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_0352620.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_0353021.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_0355377.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_0358260.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_0358623.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_0359676.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_0359720.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_0361122.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# ...
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9927584.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9927724.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9927852.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9928214.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9928802.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9929302.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9930189.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\malignant
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9930607.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9931144.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9931481.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9932650.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9932714.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9935338.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9936277.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9937461.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9937768.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9938017.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9939951.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9940478.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9941030.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9941424.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9941666.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\malignant
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9941770.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9943876.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9944611.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9945261.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9948144.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9948221.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9948885.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9950945.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9951257.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9951368.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9951402.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9952355.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9952818.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9954377.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9955398.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9955410.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9956468.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9957341.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9957368.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\malignant
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9960485.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9960583.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9960678.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9960693.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9961370.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9962990.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9963263.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9963289.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9967412.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9968023.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9968300.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9968928.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9969308.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9969800.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9970992.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9972828.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9973011.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9973102.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9975957.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9976054.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9976538.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9978346.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9979369.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9979673.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9980216.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\malignant
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9980453.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9982380.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9982577.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9982814.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9983015.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9983147.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9983668.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9986023.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9987035.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9987545.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9989537.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9989558.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9990202.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9990629.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9991958.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9992226.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9992485.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9996992.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9997917.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9998234.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Moved G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\ISIC_2020_Test_JPEG\ISIC_2020_Test_Input\ISIC_9999302.jpg to G:\OneDrive\ML-MinorProject\ISIC-2020 Dataset\processed_test\benign
# Number of benign images in processed_test: 10720
# Number of malignant images in processed_test: 262

# %% [markdown]
# ## 7. Load Train Ground Truth

# %%
# Load train ground truth
train_ground_truth_csv_path = os.path.join(BASE_DIR, "ISIC_2020_Training_GroundTruth.csv")
train_ground_truth_df = pd.read_csv(train_ground_truth_csv_path)

# Create dataframe for train data
train_filenames = glob.glob(os.path.join(TRAIN_DIR, "*.jpg"))
train_ground_truth_df["filename"] = train_ground_truth_df["image_name"].apply(lambda x: os.path.join(TRAIN_DIR, f"{x}.jpg"))
train_ground_truth_df["label"] = train_ground_truth_df["target"].apply(lambda x: "malignant" if x == 1 else "benign")

# %% [markdown]
# ## 8. Splitting the Train images
# We split the train images into train set and validation set.

# %%
# Split training data into train and validation sets
train_split_df, val_split_df = train_test_split(
    train_ground_truth_df, test_size=0.2, random_state=42, stratify=train_ground_truth_df["label"]
)

# %% [markdown]
# ## 9. Move Images
# We move the images to `processed_train` images and `processed_val` images in accordance to the split.

# %%
# Move training images to processed_train directory
for _, row in train_split_df.iterrows():
    label = row["label"]
    src_path = row["filename"]
    dest_dir = os.path.join(PROCESSED_TRAIN_DIR, label)
    if os.path.exists(src_path):  # Ensure the file exists before moving
        shutil.move(src_path, os.path.join(dest_dir, os.path.basename(src_path)))

# Move validation images to processed_val directory
for _, row in val_split_df.iterrows():
    label = row["label"]
    src_path = row["filename"]
    dest_dir = os.path.join(PROCESSED_VAL_DIR, label)
    if os.path.exists(src_path):  # Ensure the file exists before moving
        shutil.move(src_path, os.path.join(dest_dir, os.path.basename(src_path)))

# %% [markdown]
# ## Conclusion
#
# The data preprocessing is complete, and the images are ready for training the models.
